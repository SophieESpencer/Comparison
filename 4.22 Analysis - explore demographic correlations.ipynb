# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", None)
df= pd.read_excel('dfwavgscores.xlsx')

# %%
demographic_info_columns = ['Country', 'ASBH02A', 'ASBH02B', 'ASBH03A', 'ASBH04', 'ASBH15A', 'ASBH15B', 'ASBH16', 'ASBH17A', 'ASBH17B', 'ASBH18AA', 'ASBH18AB', 'ASBG01', 'ASBG03','MINAGEARRIVAL', 'rounded_ages','ASDAGE','avgscore']

# %%
df_demo = df[demographic_info_columns]

# %%
pivot_langoftest = df_demo.pivot_table(values='avgscore', index=['Country','ASBH02A'],columns=['ASBH04'] )

# %%
pivot_langoftest
# Out:
# ASBH04                      1.0         2.0         3.0         4.0
# Country     ASBH02A
# Austria     No       526.568683  499.076921  489.982926  518.437218
#             Yes      548.440280  513.888546  477.016948  459.554538
# Egypt       No       380.287685  359.878675  377.917497  263.399871
#             Yes      381.613082  380.178017  382.486908  362.437696
# France      No       511.447470  496.336046  458.852563  487.225042
#             Yes      524.655744  505.915474  467.705766  496.661765
# Jordan      No       384.344459  375.184140  380.041626  350.377802
#             Yes      370.903979  356.796237  360.648001  325.172960
# Netherlands No       538.941632  545.478924  491.142007  530.608261
#             Yes      545.374390  545.130593  541.409542  556.160668
# Sweden      No       545.221577  507.098497  501.383882  534.593889
#             Yes      571.743100  541.003457  538.147637  541.857496

# %%
plt.figure(figsize=(8, 6))

# Create the heatmap
sns.heatmap(pivot_langoftest, annot=False, cmap='coolwarm')

# Add a title
plt.title('langoftest Matrix Heatmap')

# Show the plot
plt.show()

# %% [markdown]
# ## Parent level of education

# %%
pivot_parentlevelofedu = df_demo.pivot_table(values='avgscore', index=['Country','ASBH02A'],columns=['ASBH15A','ASBH15B'] )

# %%
pivot_parentlevelofedu
# Out:
# ASBH15A                    1.0                                       \
# ASBH15B                    1.0         2.0         3.0         4.0
# Country     ASBH02A
# Austria     No       435.659564         NaN         NaN  528.195355
#             Yes      420.646031         NaN         NaN  408.735574
# Egypt       No       404.327629  296.456540         NaN  482.771890
#             Yes      343.547233  332.637388  341.394762  349.928624
# France      No       498.387656         NaN  368.374409         NaN
#             Yes      505.283577  591.382984         NaN  489.685435
# Jordan      No       336.795693  353.869954  411.155682  303.974172
#             Yes      299.282079  320.698007  319.931453  350.161576
# Netherlands No              NaN         NaN         NaN         NaN
#             Yes      525.952762         NaN         NaN         NaN
# Sweden      No       498.779777         NaN         NaN         NaN
#             Yes      475.466987         NaN         NaN  560.624655
#
# ASBH15A                                                              \
# ASBH15B                    5.0         6.0         7.0         9.0
# Country     ASBH02A
# Austria     No              NaN         NaN         NaN         NaN
#             Yes             NaN         NaN         NaN         NaN
# Egypt       No              NaN         NaN  372.002924         NaN
#             Yes      362.071663  275.321025         NaN  317.194583
# France      No              NaN         NaN         NaN         NaN
#             Yes             NaN         NaN  442.321528         NaN
# Jordan      No       468.744458         NaN  261.597630  370.530445
#             Yes      380.395070  362.018027  347.698645  334.524347
# Netherlands No              NaN  497.568294         NaN         NaN
#             Yes             NaN         NaN         NaN         NaN
# Sweden      No              NaN         NaN         NaN  349.611278
#             Yes             NaN         NaN         NaN         NaN
#
# ASBH15A                                2.0                           \
# ASBH15B                    10.0        1.0         2.0         3.0
# Country     ASBH02A
# Austria     No              NaN         NaN  484.186130  472.363134
#             Yes             NaN  591.224610  491.087455  474.696791
# Egypt       No              NaN         NaN         NaN         NaN
#             Yes      373.473437  340.340349  359.251851  355.051628
# France      No              NaN  415.984152  482.578884  543.540855
#             Yes             NaN  465.053132  475.471547  559.233620
# Jordan      No       479.301391  356.527073  345.672318  350.577212
#             Yes      277.618539  289.773675  308.076817  326.277388
# Netherlands No              NaN         NaN         NaN         NaN
#             Yes             NaN         NaN  462.156375  452.698908
# Sweden      No              NaN  594.196354  493.267757  505.379508
#             Yes             NaN  577.202528  518.817013  575.314595
#
# ASBH15A                                                              \
# ASBH15B                    4.0         5.0         6.0         7.0
# Country     ASBH02A
# Austria     No       389.176339         NaN         NaN         NaN
#             Yes      465.956626  542.575546  594.325635  441.959557
# Egypt       No       455.213302  347.536216  343.340501         NaN
#             Yes      364.825985  304.838652  336.854821  514.854116
# France      No       554.655328         NaN  543.676189         NaN
#             Yes      486.634570         NaN  510.463941         NaN
# Jordan      No       313.215371  293.284828  481.762655  418.547075
#             Yes      307.070362  318.749128  405.056936  397.888121
# Netherlands No              NaN         NaN         NaN         NaN
#             Yes      510.969313         NaN         NaN         NaN
# Sweden      No       422.794839         NaN  468.566292  543.628806
#             Yes      525.695819  530.554828         NaN  404.865234
#
# ASBH15A                                                        3.0   \
# ASBH15B                    8.0         9.0         10.0        1.0
# Country     ASBH02A
# Austria     No              NaN         NaN         NaN  480.268156
#             Yes             NaN         NaN         NaN  432.487777
# Egypt       No              NaN         NaN         NaN  329.426430
#             Yes             NaN  413.996876  386.925306  356.552244
# France      No       444.545003         NaN         NaN  547.105802
#             Yes      426.515223         NaN         NaN  441.889222
# Jordan      No              NaN  415.930063         NaN  411.384853
#             Yes             NaN  455.915493         NaN  339.955556
# Netherlands No              NaN         NaN         NaN  495.619706
#             Yes             NaN         NaN         NaN         NaN
# Sweden      No              NaN         NaN         NaN  486.760183
#             Yes             NaN         NaN         NaN         NaN
#
# ASBH15A                                                              \
# ASBH15B                    2.0         3.0         4.0         5.0
# Country     ASBH02A
# Austria     No       489.646965  469.306997  460.709012  521.133544
#             Yes      457.388701  472.288571  503.485503  461.270118
# Egypt       No              NaN  505.672245  429.761128         NaN
#             Yes      354.448126  375.630805  367.230683  416.317361
# France      No       477.282274  522.071734  489.271852         NaN
#             Yes      516.701159  492.519475  491.349477         NaN
# Jordan      No       397.074677  383.021198  393.261898  370.523969
#             Yes      296.254878  324.668944  335.093232  341.573647
# Netherlands No       526.962723         NaN  485.563502         NaN
#             Yes      447.969023  517.398057  519.846771         NaN
# Sweden      No       436.524300  401.512786  429.462687  615.173134
#             Yes      517.490414  455.324803  546.061932  535.186262
#
# ASBH15A                                                              \
# ASBH15B                    6.0         7.0         8.0         9.0
# Country     ASBH02A
# Austria     No       486.802636  444.995511         NaN         NaN
#             Yes      515.285924  517.698169  541.437797         NaN
# Egypt       No              NaN         NaN         NaN         NaN
#             Yes      350.653090  505.627377         NaN  309.010614
# France      No              NaN  527.091710         NaN         NaN
#             Yes      501.000697  525.999617  568.212828  565.095869
# Jordan      No       471.901555  435.363684         NaN  381.883802
#             Yes      373.293202  360.900015  207.749426  283.755566
# Netherlands No              NaN  549.796963         NaN         NaN
#             Yes      525.411224  523.760017  538.774325         NaN
# Sweden      No              NaN  497.055895         NaN         NaN
#             Yes      574.157741  493.288979  424.537267         NaN
#
# ASBH15A                                4.0                           \
# ASBH15B                    10.0        1.0         2.0         3.0
# Country     ASBH02A
# Austria     No              NaN         NaN  434.491547  504.645389
#             Yes      498.509806  476.318546  462.436205  478.859115
# Egypt       No              NaN  346.129745  387.063023  369.839977
#             Yes      447.499906  321.608252  344.502530  383.409668
# France      No              NaN  538.779686  472.687045  452.116408
#             Yes      634.074685  482.534867  485.275066  488.824721
# Jordan      No       403.079856  522.608513  458.026392  413.675795
#             Yes      419.732346  364.436126  369.752788  354.731226
# Netherlands No              NaN         NaN         NaN  494.992694
#             Yes      523.495499  522.407743  529.775020  523.480970
# Sweden      No              NaN         NaN  524.161330  479.456730
#             Yes             NaN  486.369931  555.195206  543.527928
#
# ASBH15A                                                              \
# ASBH15B                    4.0         5.0         6.0         7.0
# Country     ASBH02A
# Austria     No       491.273500  490.447416  483.295301  491.575025
#             Yes      519.115542  533.460468  547.816654  544.962596
# Egypt       No       415.364513  371.226979  373.205289         NaN
#             Yes      393.660410  392.714626  405.131711  402.938517
# France      No       511.157388         NaN  500.706515  529.285319
#             Yes      499.478359  514.178882  518.969443  540.023740
# Jordan      No       391.258215  516.819465  361.323946  378.664846
#             Yes      355.603149  359.787421  381.904024  400.111740
# Netherlands No       466.561319         NaN         NaN  573.587841
#             Yes      528.325690         NaN  525.009898  553.067185
# Sweden      No       519.335017  486.636284  532.350375  509.591405
#             Yes      547.572265  552.376694  566.182835  555.509551
#
# ASBH15A                                                        5.0   \
# ASBH15B                    8.0         9.0         10.0        1.0
# Country     ASBH02A
# Austria     No       518.184880  580.580107  536.796621         NaN
#             Yes      565.356410  566.149818  526.536550         NaN
# Egypt       No              NaN         NaN         NaN         NaN
#             Yes      376.283136  442.305860  364.347732  365.850592
# France      No       576.496857         NaN         NaN         NaN
#             Yes      545.184360  489.662811  511.810081         NaN
# Jordan      No       315.759324  495.218841         NaN         NaN
#             Yes      238.681156  370.063881  411.664169  360.819003
# Netherlands No       558.525650         NaN         NaN         NaN
#             Yes      545.281026  500.404058  487.389618         NaN
# Sweden      No       554.390247  536.013648         NaN         NaN
#             Yes      593.735984  511.004381  557.672702         NaN
#
# ASBH15A                                                              \
# ASBH15B                    2.0         3.0         4.0         5.0
# Country     ASBH02A
# Austria     No              NaN         NaN  453.685796         NaN
#             Yes             NaN  458.145949  540.363307  537.152709
# Egypt       No              NaN         NaN         NaN  423.177089
#             Yes      347.420302  420.090271  353.545970  391.257337
# France      No              NaN         NaN  558.083512  469.406183
#             Yes      531.838143  518.394381  523.713249  505.874761
# Jordan      No       421.397392  467.369369  423.887624  494.482882
#             Yes      365.007412  312.802542  343.821003  376.375898
# Netherlands No              NaN         NaN         NaN         NaN
#             Yes             NaN         NaN         NaN         NaN
# Sweden      No              NaN  511.852978  561.942645  520.974358
#             Yes      530.605027  556.056953  538.505017  546.765543
#
# ASBH15A                                                              \
# ASBH15B                    6.0         7.0         8.0         9.0
# Country     ASBH02A
# Austria     No              NaN  498.875535         NaN         NaN
#             Yes      551.969501  455.299328  551.007875         NaN
# Egypt       No              NaN  407.700321  474.613187         NaN
#             Yes      384.918974  406.370653  487.492180  373.706250
# France      No       545.711597         NaN         NaN         NaN
#             Yes      518.965195  508.542390  526.151607  531.644841
# Jordan      No       454.513183  373.474866         NaN  423.262844
#             Yes      373.225416  407.957404  559.320427  404.406992
# Netherlands No              NaN         NaN         NaN         NaN
#             Yes             NaN         NaN         NaN         NaN
# Sweden      No       438.694007  529.295018  537.018380  391.745128
#             Yes      550.838989  577.683239  575.510603  513.656629
#
# ASBH15A                                6.0                           \
# ASBH15B                    10.0        1.0         2.0         3.0
# Country     ASBH02A
# Austria     No              NaN         NaN  364.964079  530.509588
#             Yes             NaN         NaN  553.886823  526.679349
# Egypt       No              NaN  186.562840  294.534286         NaN
#             Yes      506.388486  347.068424  430.887707  392.017358
# France      No              NaN         NaN         NaN  609.215779
#             Yes      577.294486         NaN  468.511491  513.686800
# Jordan      No              NaN         NaN         NaN  345.514261
#             Yes      341.083806  342.385660  390.298816  343.172292
# Netherlands No              NaN         NaN         NaN         NaN
#             Yes             NaN         NaN         NaN  517.700040
# Sweden      No       521.053851         NaN         NaN  473.043913
#             Yes      514.231526  496.794533  513.135491  548.100603
#
# ASBH15A                                                              \
# ASBH15B                    4.0         5.0         6.0         7.0
# Country     ASBH02A
# Austria     No       488.794897  482.960170  487.361951  469.839578
#             Yes      538.262407  548.172624  554.053646  540.641391
# Egypt       No       328.950157  328.349228  256.517601  427.616873
#             Yes      364.452964  377.643825  385.911427  385.159230
# France      No       503.445890         NaN  516.712175  559.893539
#             Yes      519.396299  507.836908  539.296641  551.546159
# Jordan      No       408.920740  417.391804  428.354619  397.079754
#             Yes      394.521814  405.092357  406.163726  448.839189
# Netherlands No       536.015507         NaN  555.989979         NaN
#             Yes      540.245451         NaN  523.708133  529.729823
# Sweden      No       523.676484  431.851795  514.345842  560.103370
#             Yes      546.514962  570.629993  570.228267  567.181768
#
# ASBH15A                                                        7.0   \
# ASBH15B                    8.0         9.0         10.0        1.0
# Country     ASBH02A
# Austria     No       567.175708  404.156528         NaN         NaN
#             Yes      578.521334  580.746285  575.280541         NaN
# Egypt       No              NaN         NaN         NaN         NaN
#             Yes      372.108774  376.366249         NaN  430.580194
# France      No       509.262577         NaN         NaN         NaN
#             Yes      549.595893  527.117721  563.739993         NaN
# Jordan      No              NaN  272.717541         NaN  380.551652
#             Yes      434.420636  297.085407  436.688770  401.633152
# Netherlands No              NaN         NaN         NaN         NaN
#             Yes      549.396113         NaN  543.056768         NaN
# Sweden      No       542.535514         NaN         NaN         NaN
#             Yes      568.419279         NaN  591.622136         NaN
#
# ASBH15A                                                              \
# ASBH15B                    2.0         3.0         4.0         5.0
# Country     ASBH02A
# Austria     No              NaN  567.268507  504.431815         NaN
#             Yes      541.926829  499.183257  548.318321  532.885416
# Egypt       No              NaN         NaN  380.525496         NaN
#             Yes      449.722861  436.275324  400.108974  371.058089
# France      No       507.986562         NaN  495.361152         NaN
#             Yes      543.914220  534.341627  521.576964  560.917221
# Jordan      No       352.853025  374.831592  414.856336  483.835438
#             Yes             NaN  409.036531  382.837204  364.919110
# Netherlands No              NaN         NaN  457.796753         NaN
#             Yes      565.992236  549.473550  544.344362         NaN
# Sweden      No              NaN  542.782789  532.137010  551.866007
#             Yes      552.899542  533.784672  561.286761  555.117859
#
# ASBH15A                                                              \
# ASBH15B                    6.0         7.0         8.0         9.0
# Country     ASBH02A
# Austria     No       528.039105  519.412581  539.855855         NaN
#             Yes      558.316497  552.333290  586.256395  586.483082
# Egypt       No       445.410376  422.716070         NaN         NaN
#             Yes      413.880932  427.578656  410.860560  486.254938
# France      No       524.802029  565.261283  606.060387         NaN
#             Yes      552.209029  560.866135  554.015935  547.375224
# Jordan      No       444.791089  456.499526  443.669265  428.820495
#             Yes      443.811963  445.627037  480.004790  449.802609
# Netherlands No              NaN  561.785372  661.894932  627.538570
#             Yes      534.498353  562.910753  558.892325  552.045866
# Sweden      No       524.578490  540.938809  548.084067  598.253820
#             Yes      571.308882  587.438067  598.354073  604.886817
#
# ASBH15A                                8.0                           \
# ASBH15B                    10.0        1.0         2.0         3.0
# Country     ASBH02A
# Austria     No       574.138017  503.213780         NaN         NaN
#             Yes      657.710989         NaN         NaN  424.788461
# Egypt       No              NaN         NaN         NaN         NaN
#             Yes             NaN         NaN         NaN         NaN
# France      No              NaN         NaN  440.781227  527.272722
#             Yes      553.271467  487.456980  531.408155  530.975212
# Jordan      No              NaN         NaN         NaN  307.566376
#             Yes      419.919549  501.715847         NaN  379.782972
# Netherlands No              NaN         NaN  544.429977         NaN
#             Yes      533.141875         NaN  486.043485  532.166116
# Sweden      No              NaN         NaN  479.912570  520.284054
#             Yes      501.827700         NaN  518.926420  509.703722
#
# ASBH15A                                                              \
# ASBH15B                    4.0         5.0         6.0         7.0
# Country     ASBH02A
# Austria     No       444.776499  464.574573  600.846917  545.595005
#             Yes      564.014378  559.165896  569.656301  576.983278
# Egypt       No              NaN         NaN         NaN  480.646345
#             Yes             NaN  370.964212  426.707960  411.953181
# France      No       482.414304         NaN  556.428627  507.829842
#             Yes      547.719095  554.742332  554.126246  563.020895
# Jordan      No       540.749464  483.493186         NaN  408.101730
#             Yes      357.655257  437.380303  481.529409  476.082879
# Netherlands No       494.894511         NaN  560.221064  564.501325
#             Yes      553.571859         NaN  579.414322  570.224703
# Sweden      No       562.384413  561.370720  482.630033  542.849618
#             Yes      563.434632  574.540630  582.249003  582.563262
#
# ASBH15A                                                        9.0   \
# ASBH15B                    8.0         9.0         10.0        1.0
# Country     ASBH02A
# Austria     No       550.380310  532.009097         NaN         NaN
#             Yes      582.887550  591.482639         NaN         NaN
# Egypt       No              NaN         NaN         NaN         NaN
#             Yes      408.089653  554.578946         NaN  441.450705
# France      No       563.867456  577.897162         NaN         NaN
#             Yes      569.301825  571.247123  583.213116         NaN
# Jordan      No       394.253471  375.122420         NaN         NaN
#             Yes      483.148888  476.870865  575.244660  330.727236
# Netherlands No       549.254053  587.101367         NaN         NaN
#             Yes      571.133055  591.608551         NaN         NaN
# Sweden      No       572.560661  510.191172         NaN         NaN
#             Yes      612.448634  606.126930  511.721140         NaN
#
# ASBH15A                                                              \
# ASBH15B                    2.0         3.0         4.0         5.0
# Country     ASBH02A
# Austria     No              NaN         NaN  522.071812  597.504430
#             Yes      359.318616         NaN  536.927186  573.337886
# Egypt       No              NaN         NaN         NaN         NaN
#             Yes             NaN  417.032324  475.439552         NaN
# France      No              NaN         NaN         NaN         NaN
#             Yes      575.467283  629.596281  574.865978  532.949682
# Jordan      No              NaN         NaN  513.185625         NaN
#             Yes      242.020774         NaN  383.090349  457.637039
# Netherlands No              NaN         NaN         NaN         NaN
#             Yes      506.463242         NaN  517.790121         NaN
# Sweden      No              NaN  583.858267         NaN         NaN
#             Yes             NaN         NaN  599.754082  610.386757
#
# ASBH15A                                                              \
# ASBH15B                    6.0         7.0         8.0         9.0
# Country     ASBH02A
# Austria     No       570.833792  581.246118  576.529716  590.927609
#             Yes      571.727429  580.441193  587.014995  593.711223
# Egypt       No              NaN  521.901062         NaN         NaN
#             Yes      434.209296  492.165705  427.303835  445.727591
# France      No              NaN         NaN  615.691084  534.423951
#             Yes      573.175863  571.621659  573.893324  581.601594
# Jordan      No              NaN  318.769971  225.558521  351.943572
#             Yes      484.362269  480.891634  384.564592  425.988289
# Netherlands No              NaN         NaN  573.202580  599.454240
#             Yes      538.778996  556.439851  572.995086  552.937115
# Sweden      No       639.665174  627.342465  567.835686  628.032880
#             Yes      621.302178  607.423624  608.463003  609.167998
#
# ASBH15A                                10.0                          \
# ASBH15B                    10.0        1.0         2.0         3.0
# Country     ASBH02A
# Austria     No              NaN         NaN         NaN         NaN
#             Yes             NaN         NaN  453.790242  430.491539
# Egypt       No              NaN         NaN         NaN         NaN
#             Yes      532.161955  407.513646         NaN  351.401118
# France      No              NaN         NaN         NaN         NaN
#             Yes             NaN         NaN  564.120619         NaN
# Jordan      No       373.830385         NaN         NaN         NaN
#             Yes      436.865153  336.352005  301.637332  444.553865
# Netherlands No              NaN         NaN         NaN         NaN
#             Yes             NaN         NaN         NaN         NaN
# Sweden      No              NaN  460.350420         NaN         NaN
#             Yes             NaN         NaN         NaN         NaN
#
# ASBH15A                                                              \
# ASBH15B                    4.0         5.0         6.0         8.0
# Country     ASBH02A
# Austria     No              NaN         NaN         NaN         NaN
#             Yes      517.185573  482.858716  540.370074         NaN
# Egypt       No              NaN         NaN         NaN         NaN
#             Yes      322.156948         NaN         NaN         NaN
# France      No              NaN         NaN         NaN         NaN
#             Yes      377.973009         NaN  467.715454  561.840831
# Jordan      No       301.250139         NaN  523.744550         NaN
#             Yes      343.783799  237.911292         NaN         NaN
# Netherlands No              NaN         NaN         NaN         NaN
#             Yes             NaN         NaN         NaN  484.465159
# Sweden      No              NaN         NaN         NaN         NaN
#             Yes      506.823182         NaN  599.492011         NaN
#
# ASBH15A
# ASBH15B                    9.0         10.0
# Country     ASBH02A
# Austria     No              NaN  484.401058
#             Yes             NaN  484.541073
# Egypt       No              NaN         NaN
#             Yes             NaN  331.776543
# France      No              NaN  492.688456
#             Yes             NaN  500.439085
# Jordan      No              NaN  330.828754
#             Yes      334.122924  312.447459
# Netherlands No              NaN  393.113856
#             Yes             NaN  472.185245
# Sweden      No              NaN  498.687835
#             Yes             NaN  540.616921

# %% [markdown]
# I need to remove missing values for this stuff to actually be interesting.

# %%
pivot_table_test = df_demo.pivot_table(
    index=['Country','ASBH02A'],
    aggfunc=lambda x: x.isnull().sum(),
)

# %%
# Calculate the total number of elements in each group
total_counts = df_demo.groupby(['Country','ASBH02A']).size()

# Calculate the percentage of missing values
percentage_missing = pivot_table_test.div(total_counts, axis=0) * 100

print("Pivot Table with Percentage of Missing Values:\n", percentage_missing)
# Out:
# Pivot Table with Percentage of Missing Values:
#                           ASBG01      ASBG03     ASBH02B   ASBH03A      ASBH04  \
# Country     ASBH02A
# Austria     No         0.000000    0.886918    0.665188  2.439024    0.221729
#             Yes        0.149068    0.521739  100.000000  0.944099    0.993789
# Egypt       No         1.413428   13.780919   22.261484  9.540636    5.300353
#             Yes        1.286947   12.530052  100.000000  2.149625    2.531467
# France      No         2.479339    2.892562    6.611570  2.066116    2.479339
#             Yes        1.988511    2.121078  100.000000  3.689792    3.490941
# Germany     No        11.616162   12.121212    0.000000  0.000000  100.000000
#             Yes        6.344411    7.207596    0.000000  0.000000  100.000000
# Iran        No       100.000000  100.000000    0.000000  0.000000  100.000000
#             Yes      100.000000  100.000000    0.017483  0.000000  100.000000
# Jordan      No         0.204290    2.145046    6.741573  2.962206    0.817160
#             Yes        0.145168    3.235172  100.000000  2.447117    1.679801
# Netherlands No         1.265823    1.265823   10.126582  2.531646    0.000000
#             Yes        0.873138    1.181305  100.000000  0.462250    0.821777
# Sweden      No         1.623377    1.948052    1.623377  2.597403    1.298701
#             Yes        0.745990    1.491981  100.000000  0.895188    0.671391
# Turkey      No       100.000000  100.000000    0.000000  0.000000  100.000000
#             Yes      100.000000  100.000000    0.000000  0.000000  100.000000
#
#                         ASBH15A     ASBH15B     ASBH16     ASBH17A  \
# Country     ASBH02A
# Austria     No        16.629712   13.968958   7.982262   60.310421
#             Yes        6.136646    5.167702   5.440994   48.670807
# Egypt       No        46.996466   61.484099  10.247350   58.303887
#             Yes       28.015839   43.925894   2.135483   42.865224
# France      No        26.446281   36.363636  16.528926   43.388430
#             Yes        7.423774   16.615113   9.589041   38.820150
# Germany     No       100.000000  100.000000   0.000000  100.000000
#             Yes      100.000000  100.000000   0.000000  100.000000
# Iran        No       100.000000  100.000000   0.000000  100.000000
#             Yes      100.000000  100.000000   0.000000  100.000000
# Jordan      No        21.859040   39.632278   8.273749   51.481103
#             Yes       21.173787   38.324347   5.101618   48.382414
# Netherlands No         7.594937   10.126582   6.329114   36.708861
#             Yes        2.876220    6.266050   4.982024   40.832049
# Sweden      No        21.428571   27.272727  12.012987   49.675325
#             Yes        7.832898   11.562850   3.916449   54.494592
# Turkey      No       100.000000  100.000000   0.000000  100.000000
#             Yes      100.000000  100.000000   0.000000  100.000000
#
#                         ASBH17B    ASBH18AA    ASBH18AB    ASDAGE  \
# Country     ASBH02A
# Austria     No        65.188470    6.651885    2.882483  0.000000
#             Yes       49.217391    4.770186    1.962733  0.000000
# Egypt       No        69.611307   13.074205   49.469965  0.000000
#             Yes       58.619714   10.309716   40.206477  0.014142
# France      No        53.305785    7.024793   26.859504  0.000000
#             Yes       42.841361    2.231551   13.256739  0.044189
# Germany     No       100.000000  100.000000  100.000000  0.000000
#             Yes      100.000000  100.000000  100.000000  0.000000
# Iran        No       100.000000  100.000000  100.000000  0.000000
#             Yes      100.000000  100.000000  100.000000  0.000000
# Jordan      No        65.985700    7.865169   41.675179  0.000000
#             Yes       65.532974    8.295313   41.766902  0.000000
# Netherlands No        46.835443    2.531646   15.189873  0.000000
#             Yes       39.445300    0.462250    7.087827  0.051361
# Sweden      No        53.571429    4.545455   18.831169  0.000000
#             Yes       50.018650    1.454681    7.609101  0.037300
# Turkey      No       100.000000  100.000000  100.000000  0.000000
#             Yes      100.000000  100.000000  100.000000  0.000000
#
#                      MINAGEARRIVAL  avgscore  rounded_ages
# Country     ASBH02A
# Austria     No          100.000000       0.0      0.000000
#             Yes         100.000000       0.0      0.000000
# Egypt       No          100.000000       0.0      0.000000
#             Yes         100.000000       0.0      0.014142
# France      No          100.000000       0.0      0.000000
#             Yes         100.000000       0.0      0.044189
# Germany     No            1.010101       0.0      0.000000
#             Yes         100.000000       0.0      0.000000
# Iran        No           25.000000       0.0      0.000000
#             Yes         100.000000       0.0      0.000000
# Jordan      No          100.000000       0.0      0.000000
#             Yes         100.000000       0.0      0.000000
# Netherlands No          100.000000       0.0      0.000000
#             Yes         100.000000       0.0      0.051361
# Sweden      No          100.000000       0.0      0.000000
#             Yes         100.000000       0.0      0.037300
# Turkey      No            1.304348       0.0      0.000000
#             Yes         100.000000       0.0      0.000000

# %%
# Create the heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(percentage_missing, annot=False, cmap='viridis', fmt='.2f')

plt.title('Percentage of Missing Values Heatmap')
plt.show()

# %% [markdown]
# I also need to remove values that are '6', meaning nan.

# %%
df_demo['ASBH15A'].value_counts()
# Out:
# 4.0     7199
# 7.0     3747
# 8.0     3086
# 6.0     2898
# 3.0     1883
# 5.0     1285
# 1.0     1009
# 2.0      959
# 9.0      727
# 10.0     212
# Name: ASBH15A, dtype: int64

# %% [markdown]
# 10 is not applicable - remove?

# %%
df_demo['ASBH15B'].value_counts()
# Out:
# 4.0     6447
# 7.0     3019
# 8.0     2614
# 6.0     2570
# 3.0     1725
# 5.0     1163
# 1.0     1025
# 2.0      846
# 9.0      619
# 10.0     235
# Name: ASBH15B, dtype: int64

# %% [markdown]
# hope for level of education - child

# %%
df_demo['ASBH16'].value_counts()
# Out:
# 6.0    16120
# 5.0    10986
# 4.0     4586
# 2.0     4469
# 3.0     2411
# 1.0     1071
# 9.0      242
# Name: ASBH16, dtype: int64

# %% [markdown]
# Let's drop all the values that have 9s - omitted. I'm not sure if this is really what I want to do but let's see.

# %%
df_demo.shape
# Out:
# (41365, 18)

# %%
# Columns to check
columns_to_check = ['ASBH02A','ASBH02B','ASBH03A','ASBH04','ASBH16','ASBH18AA','ASBH18AB']

# Drop rows where any of the specified columns have a value of 9.0
condition = (df_demo[columns_to_check] != 9.0).all(axis=1)
df_cleaned = df_demo.loc[condition]
df_cleaned.shape
# Out:
# (40810, 18)

# %%
# Columns to check
columns_to_check2 = ['ASBH15A','ASBH15B','ASBH17A','ASBH17B']

# Drop rows where any of the specified columns have a value of 999.0
condition = (df_cleaned[columns_to_check2] != 999.0).all(axis=1)
df_cleaned2 = df_cleaned.loc[condition]
df_cleaned2.shape
# Out:
# (40810, 18)

# %% [markdown]
# let's look at the columns that all countries have answers for - 02B - age when arrived in country and 3a speaking lang of test before school? check this!

# %% [markdown]
# I need to do some more cleaning if I'm getting results like this! Should not have yesses, and I guess I didn't change all results to ordinal....

# %% [markdown]
# # Getting back to exploring correlations after cleaning

# %%
pivot_langoftest = df_cleaned2.pivot_table(values='avgscore', index=['Country','ASBH02A'],columns=['ASBH03A'] )

# %%
pivot_langoftest
# Out:
# ASBH03A                      No         Yes
# Country     ASBH02A
# Austria     No       487.644450  519.200136
#             Yes      472.403527  540.354807
# Egypt       No       381.043511  372.595149
#             Yes      375.918329  381.073185
# France      No       488.363427  502.055537
#             Yes      485.858645  523.752310
# Germany     No       490.241179  517.378624
#             Yes      521.262006  547.694411
# Iran        No       445.175716  424.108638
#             Yes      362.092439  433.785116
# Jordan      No       341.963226  383.829266
#             Yes      343.067021  368.516474
# Netherlands No       492.096739  558.039226
#             Yes      523.447747  545.748518
# Sweden      No       486.508932  534.645708
#             Yes      520.077984  567.317763
# Turkey      No       436.301444  477.771726
#             Yes      472.809233  509.617613

# %%
plt.figure(figsize=(8, 6))

# Create the heatmap
sns.heatmap(pivot_langoftest, annot=False, cmap='coolwarm')

# Add a title
plt.title('langoftest Matrix Heatmap')

# Show the plot
plt.show()

# %% [markdown]
# Again I want to put the yesses on top of the nos. And do I want to arange the order?

# %% [markdown]
# Let's do a pivot adding the lang of test column to the index.

# %% [markdown]
# Now I want to see how age of arrival affects average score. I need to first clean the minagearrival column - adding 'NA' for those who were born in country

# %%
df_cleaned2['MINAGEARRIVAL'].value_counts(dropna=False)
# Out:
# NaN    40349
# 0.0      162
# 3.0      143
# 6.0      102
# 8.0       54
# Name: MINAGEARRIVAL, dtype: int64

# %%
df_cleaned2['ASBH02B'].value_counts(dropna = False)
# Out:
# NaN                         25233
# 6                           12935
# Younger than 3 years old      928
# 3 to 5 years old              692
# 6 to 7 years old              375
# 8 years old or older          186
# 1                             162
# 2                             143
# 3                             102
# 4                              54
# Name: ASBH02B, dtype: int64

# %%
df_cleaned2['MINAGEARRIVAL'] = df_cleaned2['MINAGEARRIVAL'].fillna('NA')

# %%
df_cleaned2['MINAGEARRIVAL'].value_counts(dropna=False)
# Out:
# NA     40349
# 0.0      162
# 3.0      143
# 6.0      102
# 8.0       54
# Name: MINAGEARRIVAL, dtype: int64

# %%
def populate_column(row):
    if row ['ASBH02B'] == 6:
        return 'NA'
    elif row['ASBH02B'] == 'Younger than 3 years old':
        return 0
    elif row['ASBH02B'] == '3 to 5 years old':
        return 3
    elif row['ASBH02B'] == '6 to 7 years old':
        return 6
    elif row['ASBH02B'] == '8 years old or older':
        return 8
    else:
        return row['MINAGEARRIVAL']  

# Apply the function to each row
df_cleaned2['MINAGEARRIVAL'] = df_cleaned2.apply(populate_column, axis=1)

# %%
df_cleaned2['MINAGEARRIVAL'].value_counts()
# Out:
# NA     38168
# 0.0     1090
# 3.0      835
# 6.0      477
# 8.0      240
# Name: MINAGEARRIVAL, dtype: int64

# %%
pivot_minage = df_cleaned2.pivot_table(values='avgscore', index=['Country'],columns=['MINAGEARRIVAL'],dropna = False)

# %%
pivot_minage
# Out:
# MINAGEARRIVAL         0.0         3.0         6.0         8.0          NA
# Country
# Austria        524.691549  503.023525  482.467533  472.698753  535.931404
# Egypt          382.087467  360.526565  353.167965  359.496124  380.234984
# France         514.789067  500.251059  487.735549  449.952812  522.219901
# Germany        521.986539  490.961791  485.084177  517.617192  547.194744
# Iran           415.102270  429.928154  450.368901  421.684960  423.246228
# Jordan         380.605999  385.670465  381.076742  372.786823  368.776349
# Netherlands    546.704431  510.434272  532.347393  529.268667  544.917812
# Sweden         547.588860  506.832225  496.426190  486.933911  565.960709
# Turkey         460.361803  439.893039  471.000542  446.103548  507.296871

# %%
plt.figure(figsize=(8, 6))

# Create the heatmap
sns.heatmap(pivot_minage, annot=False, cmap='YlGnBu')

# Add a title
plt.title('langoftest Matrix Heatmap')

# Show the plot
plt.show()

# %% [markdown]
# ## Other stuff

# %%
correlation_matrix = df_demo.corr()

# %%
plt.figure(figsize=(8, 6))

# Create the heatmap
sns.heatmap(correlation_matrix, annot=False, cmap='coolwarm', vmin=-1, vmax=1)

# Add a title
plt.title('Correlation Matrix Heatmap')

# Show the plot
plt.show()

# %% [markdown]
# `ASBH02A	GEN\CHILD BORN IN <COUNTRY>\
# ASBH02B	GEN\AGE OF CHILD WHEN CAME TO <COUNTRY>\
# ASBH03A	GEN\LANGUAGE<LANGUAGE OF TEST>\
# ASBH04	GEN\HOW OFTEN <LANG OF TEST> AT HOME\
# ASBH15A	GEN\LVL OF EDUCATIONGUARDIAN A\
# ASBH15B	GEN\LVL OF EDUCATIONGUARDIAN B\
# ASBH16	GEN\LVL OF EDUCATIONCHILD\
# ASBH17A	GEN\WHAT KIND OF MAIN JOB\GUARDIAN A\
# ASBH17B	GEN\WHAT KIND OF MAIN JOB\GUARDIAN B\
# ASBH18AA	GEN\LANGUAGE SPOKEN<LANGUAGE OF TEST>GUARDIAN A\
# ASBH18AB	GEN\LANGUAGE SPOKEN<LANGUAGE OF TEST>GUARDIAN B\
# ASBH18BA	GEN\LANGUAGE SPOKEN<COUNTRY-SPECIFIC>GUARDIAN A\
# ASBH18BB	GEN\LANGUAGE SPOKEN<COUNTRY-SPECIFIC>GUARDIAN B`

# %% [markdown]
# With the above I just want to focus on the bottom row really - remove the rest? There is a light negative correlation between speaking the language of test at home and the average score. Also those whose parents have more education have performed better overall. However, we can only use numerical columns for a correlation matrix. For non-numerical columns we can try the methods below.

# %% [markdown]
# # Non-numeric

# %% [markdown]
# ## The below is for comparing columns that are non-numeric. It might be worthwhile to hot-code!? these columns so that we can do .corr with them. Like the ones above. I also want to look at the ones above in more detail.

# %%
from scipy.stats import chi2_contingency

# %%
# Create a contingency table
contingency_table = pd.crosstab(df['ASBH02A'], df['avgscore'])

# %%
# Perform Chi-Square Test of Independence
chi2, p, dof, expected = chi2_contingency(contingency_table)

# %%
print(f"Chi-Square Test Statistic: {chi2}")
print(f"P-value: {p}")

# %% [markdown]
# ## Interpretation
#
# Chi-Square Test Statistic: 41365.00000000001
# P-value: 0.49630132644040176
#
# The P-value of approximately 0.496 suggests that there is a 49.6% chance of obtaining a Chi-Square Test Statistic of 41365 or higher under the assumption that the null hypothesis is true (i.e., there is no association between the variables). Since this P-value is much larger than 0.05, we do not have enough evidence to reject the null hypothesis.
#
# Conclusion
# There is no significant association between the variables in the contingency table. The high Chi-Square Test Statistic value seems unusual given the high P-value, which suggests that there might be an issue with the data or the way the test was performed. It might be useful to recheck the data or the contingency table to ensure there are no errors or anomalies.

# %%
# Create a box plot
sns.boxplot(x=df['avgscore'])

# Add title and labels
plt.title('Box Plot of Your Data')
plt.xlabel('Data')
plt.ylabel('Values')

# Show the plot
plt.show()

# %% [markdown]
# Interpretation
# Central Box: Represents the interquartile range (IQR), containing the middle 50% of the data.
# Line inside the Box: Indicates the median of the data.
# Whiskers: Extend to the smallest and largest values within 1.5 * IQR from the lower and upper quartiles.
# Dots outside the Whiskers: Represent potential outliers.

# %% [markdown]
# ## do a scatter plot\ ask chatgpt about regression and clustering

# %% [markdown]
# ## want to do experiment with crosstab - adding more columns

# %% [markdown]
# I think my data is normally distributed because there is an obvious dip for specific countries but there are no crazy dips or heights that are not normal for the country.

# %%
import plotly.express as px

# Create a contingency table with the original data
contingency_table = pd.crosstab(df['ASBH02A'], df['avgscore'])

# Convert the contingency table to a format suitable for Plotly
contingency_table_reset = contingency_table.reset_index()
contingency_table_melted = contingency_table_reset.melt(id_vars='ASBH02A', var_name='avgscore', value_name='count')

# Plot the heatmap using Plotly
fig = px.density_heatmap(contingency_table_melted, x='ASBH02A', y='avgscore', z='count', color_continuous_scale='coolwarm')
fig.update_layout(title='Heatmap of Frequency Counts')
fig.show()

# %%
def cramers_v(confusion_matrix):
    chi2 = chi2_contingency(confusion_matrix)[0]
    n = confusion_matrix.sum().sum()
    r, k = confusion_matrix.shape
    return np.sqrt(chi2 / (n * (min(r, k) - 1)))

# Create a confusion matrix
confusion_matrix = pd.crosstab(df['ASBH02A'], df['avgscore'])

# Calculate Cramér's V
cramers_v_value = cramers_v(confusion_matrix)
print(f"Cramér's V: {cramers_v_value}")

# %%
# One-hot encode the categorical variables
df_encoded = pd.get_dummies(df)

# Calculate the correlation matrix
correlation_matrix = df_encoded.corr()

# Plot the heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Correlation Matrix Heatmap for Encoded Categorical Data')
plt.show()

# %%
# Sample a subset of the data
df_sample = df.sample(n=10)  # Adjust the sample size as needed

# Create a contingency table with the sample
contingency_table = pd.crosstab(df_sample['ASBH02A'], df_sample['avgscore'])

# Plot the heatmap with the sample
plt.figure(figsize=(8, 6))
sns.heatmap(contingency_table, annot=False, cmap='coolwarm')
plt.title('Heatmap of Frequency Counts')
plt.show()

# %% [markdown]
# Rearrange order of columns -put asdage with other demographic
#
# **I want to get back all the asbg10 ones - they are useful**
# ## I can use the differing demographic data to see if there is that affects experience in schools and reading scores.
# Should also compare reading scores with the benchmark and can also compare with previous years.
# If I get data from different dates maybe I can practice the time/date stuff. change asbh02a to immigrant/ non - immigrant
