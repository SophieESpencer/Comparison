# %%
import pandas as pd
import numpy as np
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", None)
df= pd.read_excel('cleanerdata.xlsx')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50367 entries, 0 to 50366
# Data columns (total 60 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     50367 non-null  int64
#  1   Unnamed: 0.1   50367 non-null  int64
#  2   Country        50367 non-null  object
#  3   IDSTUD         50367 non-null  int64
#  4   ASBH02A        41503 non-null  object
#  5   ASBH02B        16269 non-null  object
#  6   ASBH03A        41179 non-null  object
#  7   ASBH04         27142 non-null  float64
#  8   ASBH15A        23316 non-null  float64
#  9   ASBH15B        20508 non-null  float64
#  10  ASBH16         40406 non-null  float64
#  11  ASBH17A        15016 non-null  float64
#  12  ASBH17B        12722 non-null  float64
#  13  ASBH18AA       26072 non-null  float64
#  14  ASBH18AB       21042 non-null  float64
#  15  ASBG01         37435 non-null  float64
#  16  ASBG03         36188 non-null  float64
#  17  ASBG10C        35913 non-null  float64
#  18  ASBG10D        35842 non-null  float64
#  19  ASBG10E        35864 non-null  float64
#  20  ASBG10F        35965 non-null  float64
#  21  ASBG11A        35987 non-null  float64
#  22  ASBG11B        35776 non-null  float64
#  23  ASBG11C        35654 non-null  float64
#  24  ASBG11D        35517 non-null  float64
#  25  ASBG11E        35563 non-null  float64
#  26  ASBG11F        35863 non-null  float64
#  27  ASBG11G        35727 non-null  float64
#  28  ASBG11H        35721 non-null  float64
#  29  ASBG11I        35667 non-null  float64
#  30  ASBG11J        35633 non-null  float64
#  31  ASDAGE         50358 non-null  float64
#  32  ASRREA01       50367 non-null  float64
#  33  ASRREA02       50367 non-null  float64
#  34  ASRREA03       50367 non-null  float64
#  35  ASRREA04       50367 non-null  float64
#  36  ASRREA05       50367 non-null  float64
#  37  ASRLIT01       50367 non-null  float64
#  38  ASRLIT02       50367 non-null  float64
#  39  ASRLIT03       50367 non-null  float64
#  40  ASRLIT04       50367 non-null  float64
#  41  ASRLIT05       50367 non-null  float64
#  42  ASRINF01       50367 non-null  float64
#  43  ASRINF02       50367 non-null  float64
#  44  ASRINF03       50367 non-null  float64
#  45  ASRINF04       50367 non-null  float64
#  46  ASRINF05       50367 non-null  float64
#  47  ASRIIE01       50367 non-null  float64
#  48  ASRIIE02       50367 non-null  float64
#  49  ASRIIE03       50367 non-null  float64
#  50  ASRIIE04       50367 non-null  float64
#  51  ASRIIE05       50367 non-null  float64
#  52  ASRRSI01       50367 non-null  float64
#  53  ASRRSI02       50367 non-null  float64
#  54  ASRRSI03       50367 non-null  float64
#  55  ASRRSI04       50367 non-null  float64
#  56  ASRRSI05       50367 non-null  float64
#  57  MINAGEARRIVAL  513 non-null    float64
#  58  rounded_ages   50358 non-null  float64
#  59  AASBG03        36188 non-null  float64
# dtypes: float64(53), int64(3), object(4)
# memory usage: 23.1+ MB

# %%
column_list = df.columns.to_list()
# Join the list into a single string separated by ', '
# Format each column name with quotes
formatted_columns = ', '.join(f"'{col}'" for col in column_list)

# Print the formatted string
print(formatted_columns)
# Out:
# 'Unnamed: 0', 'Unnamed: 0.1', 'Country', 'IDSTUD', 'ASBH02A', 'ASBH02B', 'ASBH03A', 'ASBH04', 'ASBH15A', 'ASBH15B', 'ASBH16', 'ASBH17A', 'ASBH17B', 'ASBH18AA', 'ASBH18AB', 'ASBG01', 'ASBG03', 'ASBG10C', 'ASBG10D', 'ASBG10E', 'ASBG10F', 'ASBG11A', 'ASBG11B', 'ASBG11C', 'ASBG11D', 'ASBG11E', 'ASBG11F', 'ASBG11G', 'ASBG11H', 'ASBG11I', 'ASBG11J', 'ASDAGE', 'ASRREA01', 'ASRREA02', 'ASRREA03', 'ASRREA04', 'ASRREA05', 'ASRLIT01', 'ASRLIT02', 'ASRLIT03', 'ASRLIT04', 'ASRLIT05', 'ASRINF01', 'ASRINF02', 'ASRINF03', 'ASRINF04', 'ASRINF05', 'ASRIIE01', 'ASRIIE02', 'ASRIIE03', 'ASRIIE04', 'ASRIIE05', 'ASRRSI01', 'ASRRSI02', 'ASRRSI03', 'ASRRSI04', 'ASRRSI05', 'MINAGEARRIVAL', 'rounded_ages', 'AASBG03'

# %%
assessment_score_columns = ['ASRREA01', 'ASRREA02', 'ASRREA03', 'ASRREA04', 'ASRREA05', 'ASRLIT01', 'ASRLIT02', 'ASRLIT03', 'ASRLIT04', 'ASRLIT05', 'ASRINF01', 'ASRINF02', 'ASRINF03', 'ASRINF04', 'ASRINF05', 'ASRIIE01', 'ASRIIE02', 'ASRIIE03', 'ASRIIE04', 'ASRIIE05', 'ASRRSI01', 'ASRRSI02', 'ASRRSI03', 'ASRRSI04', 'ASRRSI05']

# %%
non_assessment_score_columns = ['Country', 'IDSTUD', 'ASBH02A', 'ASBH02B', 'ASBH03A', 'ASBH04', 'ASBH15A', 'ASBH15B', 'ASBH16', 'ASBH17A', 'ASBH17B', 'ASBH18AA', 'ASBH18AB', 'ASBG01', 'ASBG03','MINAGEARRIVAL', 'rounded_ages','ASBG10C', 'ASBG10D', 'ASBG10E', 'ASBG10F', 'ASBG11A', 'ASBG11B', 'ASBG11C', 'ASBG11D', 'ASBG11E', 'ASBG11F', 'ASBG11G', 'ASBG11H', 'ASBG11I', 'ASBG11J']

# %%
demographic_info_columns = ['Country', 'IDSTUD', 'ASBH02A', 'ASBH02B', 'ASBH03A', 'ASBH04', 'ASBH15A', 'ASBH15B', 'ASBH16', 'ASBH17A', 'ASBH17B', 'ASBH18AA', 'ASBH18AB', 'ASBG01', 'ASBG03','MINAGEARRIVAL', 'rounded_ages']

# %%
experience_in_school_columns = ['Country','ASBG10C', 'ASBG10D', 'ASBG10E', 'ASBG10F', 'ASBG11A', 'ASBG11B', 'ASBG11C', 'ASBG11D', 'ASBG11E', 'ASBG11F', 'ASBG11G', 'ASBG11H', 'ASBG11I', 'ASBG11J']

# %%
df = df.drop('AASBG03',axis=1)

# %%
mean_of_belonging = df.groupby('ASBH02A').agg({'ASBG10C': 'mean'})
print(mean_of_belonging)
# Out:
#           ASBG10C
# ASBH02A
# 9        1.428571
# No       1.456111
# Yes      1.420919

# %%
# Calculate correlation between two columns
correlation = df['ASDAGE'].corr(df['MINAGEARRIVAL'])
print(correlation)
# Out:
# 0.1474808306134366

# %%
df.groupby("rounded_ages")["MINAGEARRIVAL"].mean()
# Out:
# rounded_ages
# 7.0          NaN
# 8.0     0.000000
# 9.0     1.781250
# 10.0    2.431227
# 11.0    3.993377
# 12.0    5.413043
# 13.0    5.875000
# 14.0    2.800000
# 99.0    8.000000
# Name: MINAGEARRIVAL, dtype: float64

# %%
pivot_df_bornincountryxreadingscore = df.pivot_table(values='ASRREA01', index='Country', columns=['ASBH02A'], aggfunc='mean')
pivot_df_bornincountryxreadingscore
# Out:
# ASBH02A               9          No         Yes
# Country
# Austria             NaN  502.126337  537.309932
# Egypt               NaN  371.054071  383.672197
# France              NaN  497.629560  522.971730
# Germany      525.967849  493.944351  548.409881
# Iran         367.597747  430.471736  423.779609
# Jordan              NaN  385.794061  371.076867
# Netherlands         NaN  533.334693  545.331998
# Sweden              NaN  513.689949  566.231783
# Turkey       479.968049  456.806291  508.673668

# %%
pivot_df_age_arrivalxreadingscore = df.pivot_table(values='ASRREA01', index='Country', columns=['ASBH02A','MINAGEARRIVAL'], aggfunc='mean')
pivot_df_age_arrivalxreadingscore
# Out:
# ASBH02A                No
# MINAGEARRIVAL         0.0         3.0         6.0         8.0
# Country
# Germany        511.920992  487.089448  488.056311  491.641326
# Iran           409.731261  440.530449  464.494811  450.532497
# Turkey         462.131911  437.054468  472.255189  452.950989

# %%
pivot_df_multiplexreadingscore = df.pivot_table(values=assessment_score_columns, index=['Country','ASBH02A'], aggfunc='mean')
pivot_df_multiplexreadingscore
# Out:
#                        ASRIIE01    ASRIIE02    ASRIIE03    ASRIIE04  \
# Country     ASBH02A
# Austria     No       501.445941  497.509870  497.003904  496.295325
#             Yes      534.842244  533.711357  533.087264  533.433242
# Egypt       No       380.239904  378.807461  369.667864  377.573304
#             Yes      383.598790  382.061023  381.942312  382.036982
# France      No       492.222485  494.421637  491.149082  494.454796
#             Yes      519.154937  518.659499  515.988722  517.479324
# Germany     9        517.016260  522.707193  527.243732  525.852375
#             No       495.935817  490.531360  491.805816  489.016677
#             Yes      543.935603  542.591778  544.966501  542.813414
# Iran        9        359.978589  365.482298  351.890479  355.298207
#             No       417.073024  412.897435  416.829988  427.544190
#             Yes      422.136523  420.909042  419.610095  420.177299
# Jordan      No       383.733002  375.714243  374.378502  377.204224
#             Yes      367.755275  365.854429  365.727323  367.295610
# Netherlands No       526.675806  527.016343  525.465012  535.101524
#             Yes      546.208978  546.738919  545.371166  544.988483
# Sweden      No       512.892926  510.925293  509.233544  505.941694
#             Yes      564.196923  562.942955  562.461770  563.588740
# Turkey      9        482.452601  485.840796  490.130404  489.901600
#             No       450.445825  451.735093  447.627363  449.679310
#             Yes      505.533630  504.930404  504.895552  504.408851
#
#                        ASRIIE05    ASRINF01    ASRINF02    ASRINF03  \
# Country     ASBH02A
# Austria     No       494.574247  500.333160  494.273331  499.723737
#             Yes      532.600417  535.331423  534.577213  531.942602
# Egypt       No       374.640233  367.082532  369.437546  366.182946
#             Yes      382.639926  386.972019  385.327706  384.657786
# France      No       492.287022  493.849162  493.760551  492.339822
#             Yes      518.967871  521.589958  520.012538  519.322934
# Germany     9        517.986038  511.108511  519.434462  526.444322
#             No       490.896966  492.766537  493.463288  491.805468
#             Yes      543.985303  544.863606  544.844930  542.004172
# Iran        9        364.681757  379.612340  379.328052  377.246503
#             No       416.353756  419.129024  408.340931  416.119405
#             Yes      420.161405  423.846058  421.546140  421.215232
# Jordan      No       377.531259  386.042868  381.378578  382.541320
#             Yes      368.023493  374.900502  371.122153  370.127569
# Netherlands No       520.819109  542.177732  525.936900  534.985537
#             Yes      545.551738  547.616100  548.393485  547.057261
#             No       423.872066  421.167890  420.931175  424.987704
#             Yes      423.103620  421.585533  423.130601  422.730166
# Jordan      No       382.779494  381.256487  383.680947  382.944507
#             Yes      367.722589  368.607815  368.121935  368.357962
# Netherlands No       533.145301  531.128153  532.665907  529.788846
#             Yes      543.960523  543.520903  544.316636  543.147296
# Sweden      No       512.248801  512.613142  516.043173  513.066092
#             Yes      565.388645  563.997768  565.672545  565.705304
# Turkey      9        485.562627  483.219501  482.939121  475.503970
#             No       453.867292  453.362850  456.556418  453.582097
#             Yes      507.844895  506.806151  505.826788  506.649474
#
#                        ASRRSI01    ASRRSI02    ASRRSI03    ASRRSI04  \
# Country     ASBH02A
# Austria     No       504.110138  501.282611  502.731472  504.290110
#             Yes      539.822371  539.194697  537.491806  539.097452
# Egypt       No       367.795331  366.914912  365.539898  359.885172
#             Yes      380.857293  378.519234  376.779103  379.005052
# France      No       493.800104  494.978625  496.004839  500.600767
#             Yes      528.152322  526.670381  527.433234  528.987934
# Germany     9        523.165371  528.917037  528.535901  530.105517
#             No       495.417629  495.728516  499.731341  494.553229
#             Yes      547.985836  546.916126  547.314931  545.892130
# Iran        9        371.939986  379.426047  365.567708  370.838404
#             No       428.359748  426.318507  434.013407  424.131404
#             Yes      425.037889  422.378775  423.324796  423.221615
# Jordan      No       386.611939  386.405766  383.243013  384.337215
#             Yes      370.088515  368.406090  366.911667  369.946442
# Netherlands No       527.777998  527.878673  528.055535  522.458158
#             Yes      545.442028  545.026065  542.580626  543.996994
# Sweden      No       516.807630  514.954204  515.671633  513.790446
#             Yes      569.020859  568.610262  567.597826  566.494989
# Turkey      9        486.326032  492.387934  492.091608  482.282185
#             No       460.381653  460.063596  454.774231  459.979016
#             Yes      511.041155  510.076148  508.188594  510.040007
#
#                        ASRRSI05
# Country     ASBH02A
# Austria     No       504.243252
#             Yes      537.100299
# Egypt       No       364.534997
#             Yes      377.859426
# France      No       490.355654
#             Yes      526.094482
# Germany     9        520.004148
#             No       497.475200
#             Yes      546.756141
# Iran        9        378.268392
#             No       435.535641
#             Yes      423.291374
# Jordan      No       383.293126
#             Yes      369.587954
# Netherlands No       530.449382
#             Yes      545.089983
# Sweden      No       516.895069
#             Yes      568.280936
# Turkey      9        500.395319
#             No       461.849227
#             Yes      510.177377

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(15,10))
ax = pivot_df_multiplexreadingscore.plot(kind='bar')
plt.title('Bar Chart')
plt.xlabel('Categories')
plt.ylabel('Values')
# Move the legend outside the plot
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5), title='Legend')

plt.show()

# %%
pivot_df_multiplexreadingscore_unstacked = pivot_df_multiplexreadingscore.unstack(level=1)
ax2 = pivot_df_multiplexreadingscore_unstacked.plot(kind='bar', figsize=(15,10), width=0.8)
plt.title('Mean Reading Scores by Country and ASBH02A')
plt.xlabel('Country')
plt.ylabel('Mean Score')
plt.legend(title='ASBH02A')
# Move the legend outside the plot
ax2.legend(loc='center left', bbox_to_anchor=(1, 0.5), title='Legend')
plt.show()

# %%
import seaborn as sns

# %%
plt.figure(figsize=(15,10))
sns.heatmap(pivot_df_multiplexreadingscore, annot=False, cmap='coolwarm')  # Set annot=False to remove values
plt.title('Mean Reading Scores by Country and ASBH02A')
plt.show()

# %% [markdown]
# We would predict darker red and lighter blue for those born in country. It is very clear that those born in Sweden do very well on these tests. There is also a striking contras between those born and not born in Turkey. This is really useful basically.
