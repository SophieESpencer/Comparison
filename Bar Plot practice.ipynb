# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.DataFrame({'A': {0: 'a', 1: 'b', 2: 'c'},
                   'B': {0: 1, 1: 3, 2: 5},
                   'C': {0: 2, 1: 4, 2: 6}})

# %%
df
# Out:
#    A  B  C
# 0  a  1  2
# 1  b  3  4
# 2  c  5  6

# %%
df.plot(kind='bar', figsize=(15,10), width=0.8)
plt.xlabel('index')
plt.ylabel('value')
# Out:
# Text(0, 0.5, 'value')

# %%
df_melted1= pd.melt(df, id_vars=['A'], value_vars=['B'])
df_melted1
# Out:
#    A variable  value
# 0  a        B      1
# 1  b        B      3
# 2  c        B      5

# %%
ax = df_melted1.plot(kind='bar', figsize=(15,10), width=0.8)
plt.xlabel('index')
plt.ylabel('Bvalue')
# Out:
# Text(0, 0.5, 'Bvalue')

# %%
df_melted2 = pd.melt(df, id_vars=['A'], value_vars=['B', 'C'])
df_melted2
# Out:
#    A variable  value
# 0  a        B      1
# 1  b        B      3
# 2  c        B      5
# 3  a        C      2
# 4  b        C      4
# 5  c        C      6

# %%
axdfmelted2 = df_melted2.plot(kind='bar', figsize=(15,10), width=0.8)
plt.xlabel('index')
plt.ylabel('variablevalue')
# Out:
# Text(0, 0.5, 'variablevalue')

# %%
import seaborn as sns

# %%
# Create the bar plot
sns.barplot(x='A', y='value', hue='variable', data=df_melted2)

# Add labels and title
plt.xlabel('A')
plt.ylabel('Value')
plt.title('Bar Plot of Column Values')

# Show the plot
plt.show()

# %%
# Pivot the melted DataFrame to get the values ready for plotting
df_pivot = df_melted2.pivot(index='A', columns='variable', values='value')

# Plotting
fig, ax = plt.subplots()

# Define bar width and positions
bar_width = 0.35
index = np.arange(len(df_pivot))

# Plot bars for each variable
bars1 = ax.bar(index, df_pivot['B'], bar_width, label='B')
bars2 = ax.bar(index + bar_width, df_pivot['C'], bar_width, label='C')

# Add labels, title, and legend
ax.set_xlabel('A')
ax.set_ylabel('Value')
ax.set_title('Bar Plot of Column Values')
ax.set_xticks(index + bar_width / 2)
ax.set_xticklabels(df_pivot.index)
ax.legend()

# Show the plot
plt.show()

# %%
df_pivot
# Out:
# variable  B  C
# A
# a         1  2
# b         3  4
# c         5  6

# %% [markdown]
# ## I want stacked and grouped but do I need a pivot table?

# %%
pivot_df_avgliteracy = df.pivot_table(values=averages, index=['Country','ASBH02A'], aggfunc='mean')
pivot_df_avgliteracy
